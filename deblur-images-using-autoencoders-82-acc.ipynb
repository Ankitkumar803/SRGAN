# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
import random
import cv2
import os
import tensorflow as tf
from tqdm import tqdm

# %%
good_frames = '../input/blur-dataset/sharp'
bad_frames = '../input/blur-dataset/defocused_blurred'

# %%
clean_frames = []
for file in tqdm(sorted(os.listdir(good_frames))):
    if any(extension in file for extension in ['.jpg', 'jpeg', '.png']):
        image = tf.keras.preprocessing.image.load_img(good_frames + '/' + file, target_size=(128,128))
        image = tf.keras.preprocessing.image.img_to_array(image).astype('float32') / 255
        clean_frames.append(image)

clean_frames = np.array(clean_frames)
blurry_frames = []
for file in tqdm(sorted(os.listdir(bad_frames))):
    if any(extension in file for extension in ['.jpg', 'jpeg', '.png']):
        image = tf.keras.preprocessing.image.load_img(bad_frames + '/' + file, target_size=(128,128))
        image = tf.keras.preprocessing.image.img_to_array(image).astype('float32') / 255
        blurry_frames.append(image)

blurry_frames = np.array(blurry_frames)
# Out:
# 100%|██████████| 350/350 [00:19<00:00, 18.30it/s]
# 100%|██████████| 350/350 [00:16<00:00, 21.49it/s]

# %%
from keras.layers import Dense, Input
from keras.layers import Conv2D, Flatten
from keras.layers import Reshape, Conv2DTranspose
from keras.models import Model
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from keras.utils.vis_utils import plot_model
from keras import backend as K

seed = 21
random.seed = seed
np.random.seed = seed

# %%
x = clean_frames;
y = blurry_frames;
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
print(x_train[0].shape)
print(y_train[0].shape)
# Out:
# (128, 128, 3)
# (128, 128, 3)

# %%
r = random.randint(0, len(clean_frames)-1)
print(r)
fig = plt.figure()
fig.subplots_adjust(hspace=0.1, wspace=0.2)
ax = fig.add_subplot(1, 2, 1)
ax.imshow(clean_frames[r])
ax = fig.add_subplot(1, 2, 2)
ax.imshow(blurry_frames[r])
# Out:
# 208

# %%
# Network Parameters
input_shape = (128, 128, 3)
batch_size = 32
kernel_size = 3
latent_dim = 256

# Encoder/Decoder number of CNN layers and filters per layer
layer_filters = [64, 128, 256]

# %%
inputs = Input(shape = input_shape, name = 'encoder_input')
x = inputs

# %%
for filters in layer_filters:
    x = Conv2D(filters=filters,
               kernel_size=kernel_size,
               strides=2,
               activation='relu',
               padding='same')(x)
shape = K.int_shape(x)
x = Flatten()(x)
latent = Dense(latent_dim, name='latent_vector')(x)
# Out:
# 2022-07-14 07:14:20.749011: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-14 07:14:20.859793: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-14 07:14:20.860695: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-14 07:14:20.861788: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-14 07:14:20.862125: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-14 07:14:20.862827: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-14 07:14:20.863461: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-14 07:14:23.313120: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-14 07:14:23.314022: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-14 07:14:23.314687: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-14 07:14:23.315274: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
encoder = Model(inputs, latent, name='encoder')
encoder.summary()
# Out:
# Model: "encoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, 128, 128, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 64, 64, 64)        1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 128)       73856
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 256)       295168
# _________________________________________________________________
# flatten (Flatten)            (None, 65536)             0
# _________________________________________________________________
# latent_vector (Dense)        (None, 256)               16777472
# =================================================================
# Total params: 17,148,288
# Trainable params: 17,148,288
# Non-trainable params: 0
# _________________________________________________________________

# %%
latent_inputs = Input(shape=(latent_dim,), name='decoder_input')
x = Dense(shape[1]*shape[2]*shape[3])(latent_inputs)
x = Reshape((shape[1], shape[2], shape[3]))(x)
for filters in layer_filters[::-1]:
    x = Conv2DTranspose(filters=filters,
                        kernel_size=kernel_size,
                        strides=2,
                        activation='relu',
                        padding='same')(x)

outputs = Conv2DTranspose(filters=3,
                          kernel_size=kernel_size,
                          activation='sigmoid',
                          padding='same',
                          name='decoder_output')(x)

# %%
decoder = Model(latent_inputs, outputs, name='decoder')
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# decoder_input (InputLayer)   [(None, 256)]             0
# _________________________________________________________________
# dense (Dense)                (None, 65536)             16842752
# _________________________________________________________________
# reshape (Reshape)            (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 32, 32, 256)       590080
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 64, 64, 128)       295040
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 128, 128, 64)      73792
# _________________________________________________________________
# decoder_output (Conv2DTransp (None, 128, 128, 3)       1731
# =================================================================
# Total params: 17,803,395
# Trainable params: 17,803,395
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder = Model(inputs, decoder(encoder(inputs)), name='autoencoder')
autoencoder.summary()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   [(None, 128, 128, 3)]     0
# _________________________________________________________________
# encoder (Functional)         (None, 256)               17148288
# _________________________________________________________________
# decoder (Functional)         (None, 128, 128, 3)       17803395
# =================================================================
# Total params: 34,951,683
# Trainable params: 34,951,683
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.compile(loss='mse', optimizer='adam',metrics=["acc"])

# %%
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               verbose=1,
                               min_lr=0.5e-6)

# %%
callbacks = [lr_reducer]
history = autoencoder.fit(blurry_frames,
                      clean_frames,
                      validation_data=(blurry_frames, clean_frames),
                      epochs=100,
                      batch_size=batch_size,
                      callbacks=callbacks)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 1s 113ms/step - loss: 0.0099 - acc: 0.7055 - val_loss: 0.0095 - val_acc: 0.7096
# Epoch 2/100
# 9/9 [==============================] - 1s 88ms/step - loss: 0.0096 - acc: 0.7122 - val_loss: 0.0092 - val_acc: 0.7248
# Epoch 3/100
# 9/9 [==============================] - 1s 85ms/step - loss: 0.0093 - acc: 0.7275 - val_loss: 0.0093 - val_acc: 0.7262
# Epoch 4/100
# 9/9 [==============================] - 1s 90ms/step - loss: 0.0093 - acc: 0.7136 - val_loss: 0.0089 - val_acc: 0.7140
# Epoch 5/100
# 9/9 [==============================] - 1s 85ms/step - loss: 0.0091 - acc: 0.7214 - val_loss: 0.0086 - val_acc: 0.7158
# Epoch 6/100
# 9/9 [==============================] - 1s 85ms/step - loss: 0.0087 - acc: 0.7270 - val_loss: 0.0087 - val_acc: 0.7419
# Epoch 7/100
# 9/9 [==============================] - 1s 86ms/step - loss: 0.0087 - acc: 0.7315 - val_loss: 0.0083 - val_acc: 0.7032
# Epoch 8/100
# 9/9 [==============================] - 1s 88ms/step - loss: 0.0084 - acc: 0.7142 - val_loss: 0.0080 - val_acc: 0.7525
# Epoch 9/100
# 9/9 [==============================] - 1s 90ms/step - loss: 0.0082 - acc: 0.7433 - val_loss: 0.0081 - val_acc: 0.7413
# Epoch 10/100
# 9/9 [==============================] - 1s 91ms/step - loss: 0.0081 - acc: 0.7342 - val_loss: 0.0078 - val_acc: 0.7515
# Epoch 11/100
# 9/9 [==============================] - 1s 87ms/step - loss: 0.0078 - acc: 0.7495 - val_loss: 0.0076 - val_acc: 0.7379
# Epoch 12/100
# 9/9 [==============================] - 1s 84ms/step - loss: 0.0077 - acc: 0.7399 - val_loss: 0.0074 - val_acc: 0.7486
# Epoch 13/100
# 9/9 [==============================] - 1s 85ms/step - loss: 0.0076 - acc: 0.7389 - val_loss: 0.0074 - val_acc: 0.7417
# Epoch 14/100
# 9/9 [==============================] - 1s 85ms/step - loss: 0.0074 - acc: 0.7488 - val_loss: 0.0072 - val_acc: 0.7507
# Epoch 15/100
# 9/9 [==============================] - 1s 87ms/step - loss: 0.
100
# 9/9 [==============================] - 1s 86ms/step - loss: 0.0021 - acc: 0.8161 - val_loss: 0.0021 - val_acc: 0.8176
# Epoch 71/100
# 9/9 [==============================] - 1s 86ms/step - loss: 0.0021 - acc: 0.8185 - val_loss: 0.0020 - val_acc: 0.8184
# Epoch 72/100
# 9/9 [==============================] - 1s 85ms/step - loss: 0.0020 - acc: 0.8187 - val_loss: 0.0020 - val_acc: 0.8178
# Epoch 73/100
# 9/9 [==============================] - 1s 85ms/step - loss: 0.0020 - acc: 0.8184 - val_loss: 0.0020 - val_acc: 0.8192
# Epoch 74/100
# 9/9 [==============================] - 1s 85ms/step - loss: 0.0020 - acc: 0.8191 - val_loss: 0.0020 - val_acc: 0.8198
# Epoch 75/100
# 9/9 [==============================] - 1s 85ms/step - loss: 0.0020 - acc: 0.8199 - val_loss: 0.0020 - val_acc: 0.8193
# Epoch 76/100
# 9/9 [==============================] - 1s 86ms/step - loss: 0.0020 - acc: 0.8199 - val_loss: 0.0020 - val_acc: 0.8211
# Epoch 77/100
# 9/9 [==============================] - 1s 85ms/step - loss: 0.0019 - acc: 0.8213 - val_loss: 0.0019 - val_acc: 0.8218
#
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 0.00010000000639606199.
# Epoch 78/100
# 9/9 [==============================] - 1s 87ms/step - loss: 0.0019 - acc: 0.8214 - val_loss: 0.0019 - val_acc: 0.8219
# Epoch 79/100
# 9/9 [==============================] - 1s 100ms/step - loss: 0.0019 - acc: 0.8210 - val_loss: 0.0019 - val_acc: 0.8216
# Epoch 80/100
# 9/9 [==============================] - 1s 96ms/step - loss: 0.0019 - acc: 0.8217 - val_loss: 0.0019 - val_acc: 0.8216
# Epoch 81/100
# 9/9 [==============================] - 1s 88ms/step - loss: 0.0019 - acc: 0.8218 - val_loss: 0.0019 - val_acc: 0.8220
# Epoch 82/100
# 9/9 [==============================] - 1s 90ms/step - loss: 0.0019 - acc: 0.8221 - val_loss: 0.0019 - val_acc: 0.8218
# Epoch 83/100
# 9/9 [==============================] - 1s 87ms/step - loss: 0.0019 - acc: 0.8219 - val_loss: 0.0019 - val_acc: 0.8221
# Epoch 84/100
# 9/9 [==============================] - 1s 85ms/step - loss: 0.0019 - acc: 0.8219 - val_loss: 0.0019 - val_acc: 0.8224
#
# Epoch 00084: ReduceLROnPlateau reducing learning rate to 3.1622778103685084e-05.
# Epoch 85/100
# 9/9 [==============================] - 1s 87ms/step - loss: 0.0019 - acc: 0.8223 - val_loss: 0.0019 - val_acc: 0.8224
# Epoch 86/100
# 9/9 [==============================] - 1s 86ms/step - loss: 0.0019 - acc: 0.8220 - val_loss: 0.0019 - val_acc: 0.8220
# Epoch 87/100
# 9/9 [==============================] - 1s 87ms/step - loss: 0.0019 - acc: 0.8221 - val_loss: 0.0019 - val_acc: 0.8223
# Epoch 88/100
# 9/9 [==============================] - 1s 86ms/step - loss: 0.0019 - acc: 0.8226 - val_loss: 0.0019 - val_acc: 0.8227
# Epoch 89/100
# 9/9 [==============================] - 1s 86ms/step - loss: 0.0019 - acc: 0.8226 - val_loss: 0.0019 - val_acc: 0.8224
#
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 1.0000000409520217e-05.
# Epoch 90/100
# 9/9 [==============================] - 1s 85ms/step - loss: 0.0019 - acc: 0.8224 - val_loss: 0.0019 - val_acc: 0.8225
# Epoch 91/100
# 9/9 [==============================] - 1s 86ms/step - loss: 0.0019 - acc: 0.8225 - val_loss: 0.0019 - val_acc: 0.8226
# Epoch 92/100
# 9/9 [==============================] - 1s 88ms/step - loss: 0.0019 - acc: 0.8225 - val_loss: 0.0019 - val_acc: 0.8225
# Epoch 93/100
# 9/9 [==============================] - 1s 86ms/step - loss: 0.0019 - acc: 0.8226 - val_loss: 0.0019 - val_acc: 0.8226
# Epoch 94/100
# 9/9 [==============================] - 1s 88ms/step - loss: 0.0019 - acc: 0.8225 - val_loss: 0.0019 - val_acc: 0.8225
#
# Epoch 00094: ReduceLROnPlateau reducing learning rate to 3.1622778678900043e-06.
# Epoch 95/100
# 9/9 [==============================] - 1s 87ms/step - loss: 0.0019 - acc: 0.8225 - val_loss: 0.0019 - val_acc: 0.8225
# Epoch 96/100
# 9/9 [==============================] - 1s 87ms/step - loss: 0.0019 - acc: 0.8225 - val_loss: 0.0019 - val_acc: 0.8226
# Epoch 97/100
# 9/9 [==============================] - 1s 90ms/step - loss: 0.0019 - acc: 0.8225 - val_loss: 0.0019 - val_acc: 0.8225
# Epoch 98/100
# 9/9 [==============================] - 1s 87ms/step - loss: 0.0019 - acc: 0.8225 - val_loss: 0.0019 - val_acc: 0.8225
# Epoch 99/100
# 9/9 [==============================] - 1s 86ms/step - loss: 0.0019 - acc: 0.8225 - val_loss: 0.0019 - val_acc: 0.8225
#
# Epoch 00099: ReduceLROnPlateau reducing learning rate to 1.0000000553323957e-06.
# Epoch 100/100
# 9/9 [==============================] - 1s 85ms/step - loss: 0.0019 - acc: 0.8225 - val_loss: 0.0019 - val_acc: 0.8225

# %%
print("\n       Input                        Ground Truth                  Predicted Value")
for i in range(3):
    
    r = random.randint(0, len(clean_frames)-1)

    x, y = blurry_frames[r],clean_frames[r]
    x_inp=x.reshape(1,128,128,3)
    result = autoencoder.predict(x_inp)
    result = result.reshape(128,128,3)

    fig = plt.figure(figsize=(12,10))
    fig.subplots_adjust(hspace=0.1, wspace=0.2)

    ax = fig.add_subplot(1, 3, 1)
    ax.imshow(x)

    ax = fig.add_subplot(1, 3, 2)
    ax.imshow(y)

    ax = fig.add_subplot(1, 3, 3)
    plt.imshow(result)
# Out:
#        Input                        Ground Truth                  Predicted Value

# %%
plt.figure(figsize=(12,8))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Train', 'Test'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.xticks(np.arange(0, 101, 25))
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.legend(['Train', 'Test'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.xticks(np.arange(0, 101, 25))
plt.show()

# %% [markdown]
# Kindly upvote!
